# %% [markdown]
# <a href="https://colab.research.google.com/github/Azzahry/JF-section-6/blob/main/BigDataAnalysis_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
os.environ['KAGGLE_CONFIG_DIR']='/content/drive/MyDrive/Data_Sains/BigDataAnalysis'

# %%
import pandas as pd

# %% [markdown]
# # **Student Info EDA**

# %%
df1 = pd.read_csv('/content/drive/MyDrive/Data_Sains/BigDataAnalysis/studentInfo.csv')

# %%
df1
# Out:
#       code_module code_presentation  id_student gender                region  \
# 0             AAA             2013J       11391      M   East Anglian Region
# 1             AAA             2013J       28400      F              Scotland
# 2             AAA             2013J       30268      F  North Western Region
# 3             AAA             2013J       31604      F     South East Region
# 4             AAA             2013J       32885      F  West Midlands Region
# ...           ...               ...         ...    ...                   ...
# 32588         GGG             2014J     2640965      F                 Wales
# 32589         GGG             2014J     2645731      F   East Anglian Region
# 32590         GGG             2014J     2648187      F          South Region
# 32591         GGG             2014J     2679821      F     South East Region
# 32592         GGG             2014J     2684003      F      Yorkshire Region
#
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32593 entries, 0 to 32592
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   code_module           32593 non-null  object
#  1   code_presentation     32593 non-null  object
#  2   id_student            32593 non-null  int64
#  3   gender                32593 non-null  object
#  4   region                32593 non-null  object
#  5   highest_education     32593 non-null  object
#  6   imd_band              31482 non-null  object
#  7   age_band              32593 non-null  object
#  8   num_of_prev_attempts  32593 non-null  int64
#  9   studied_credits       32593 non-null  int64
#  10  disability            32593 non-null  object
#  11  final_result          32593 non-null  object
# dtypes: int64(3), object(9)
# memory usage: 3.0+ MB

# %%
df1.describe()
# Out:
#          id_student  num_of_prev_attempts  studied_credits
# count  3.259300e+04          32593.000000     32593.000000
# mean   7.066877e+05              0.163225        79.758691
# std    5.491673e+05              0.479758        41.071900
# min    3.733000e+03              0.000000        30.000000
# 25%    5.085730e+05              0.000000        60.000000
# 50%    5.903100e+05              0.000000        60.000000
# 75%    6.444530e+05              0.000000       120.000000
# max    2.716795e+06              6.000000       655.000000

# %%
import matplotlib.pyplot as plt

count_finalResult = df1['final_result'].value_counts()

plt.figure(figsize=(8, 6))
plt.bar(count_finalResult.index, count_finalResult.values, color=['blue', 'red', 'green', 'orange'])
plt.title('Jumlah Siswa Lulus')
plt.show()

# %% [markdown]
# # **Student Assessment EDA**

# %%
df2 = pd.read_csv('/content/drive/MyDrive/Data_Sains/BigDataAnalysis/studentAssessment.csv')

# %%
df2
# Out:
#         id_assessment  id_student  date_submitted  is_banked  score
# 0                1752       11391              18          0   78.0
# 1                1752       28400              22          0   70.0
# 2                1752       31604              17          0   72.0
# 3                1752       32885              26          0   69.0
# 4                1752       38053              19          0   79.0
# ...               ...         ...             ...        ...    ...
# 173907          37443      527538             227          0   60.0
# 173908          37443      534672             229          0  100.0
# 173909          37443      546286             215          0   80.0
# 173910          37443      546724             230          0  100.0
# 173911          37443      558486             224          0   80.0
#
# [173912 rows x 5 columns]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 173912 entries, 0 to 173911
# Data columns (total 5 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   id_assessment   173912 non-null  int64
#  1   id_student      173912 non-null  int64
#  2   date_submitted  173912 non-null  int64
#  3   is_banked       173912 non-null  int64
#  4   score           173739 non-null  float64
# dtypes: float64(1), int64(4)
# memory usage: 6.6 MB

# %%
df2.describe()
# Out:
#        id_assessment    id_student  date_submitted      is_banked  \
# count  173912.000000  1.739120e+05   173912.000000  173912.000000
# mean    26553.803556  7.051507e+05      116.032942       0.010977
# std      8829.784254  5.523952e+05       71.484148       0.104194
# min      1752.000000  6.516000e+03      -11.000000       0.000000
# 25%     15022.000000  5.044290e+05       51.000000       0.000000
# 50%     25359.000000  5.852080e+05      116.000000       0.000000
# 75%     34883.000000  6.344980e+05      173.000000       0.000000
# max     37443.000000  2.698588e+06      608.000000       1.000000
#
#                score
# count  173739.000000
# mean       75.799573
# std        18.798107
# min         0.000000
# 25%        65.000000
# 50%        80.000000
# 75%        90.000000
# max       100.000000

# %%
import numpy as np
from google.colab import autoviz

def histogram(df, colname, num_bins=20, figscale=1):
  from matplotlib import pyplot as plt
  df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
  plt.gca().spines[['top', 'right',]].set_visible(False)
  plt.tight_layout()
  return autoviz.MplChart.from_current_mpl_state()

chart = histogram(df2, *['score'], **{})
chart
# Out:
# <img src="...">
#         <script></script>

# %% [markdown]
# # **Assessment EDA**

# %%
df3 = pd.read_csv('/content/drive/MyDrive/Data_Sains/BigDataAnalysis/assessments.csv')

# %%
df3
# Out:
#     code_module code_presentation  id_assessment assessment_type   date  \
# 0           AAA             2013J           1752             TMA   19.0
# 1           AAA             2013J           1753             TMA   54.0
# 2           AAA             2013J           1754             TMA  117.0
# 3           AAA             2013J           1755             TMA  166.0
# 4           AAA             2013J           1756             TMA  215.0
# ..          ...               ...            ...             ...    ...
# 201         GGG             2014J          37443             CMA  229.0
# 202         GGG             2014J          37435             TMA   61.0
# 203         GGG             2014J          37436             TMA  124.0
# 204         GGG             2014J          37437             TMA  173.0
# 205         GGG             2014J          37444            Exam  229.0
#
#      weight
# 0      10.0
# 1      20.0
# 2      20.0
# 3      20.0
# 4      30.0
# ..      ...
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206 entries, 0 to 205
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   code_module        206 non-null    object
#  1   code_presentation  206 non-null    object
#  2   id_assessment      206 non-null    int64
#  3   assessment_type    206 non-null    object
#  4   date               195 non-null    float64
#  5   weight             206 non-null    float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 9.8+ KB

# %%
df3.describe()
# Out:
#        id_assessment        date      weight
# count     206.000000  195.000000  206.000000
# mean    26473.975728  145.005128   20.873786
# std     10098.625521   76.001119   30.384224
# min      1752.000000   12.000000    0.000000
# 25%     15023.250000   71.000000    0.000000
# 50%     25364.500000  152.000000   12.500000
# 75%     34891.750000  222.000000   24.250000
# max     40088.000000  261.000000  100.000000

# %%
def categorical_histogram(df, colname, figscale=1, mpl_palette_name='Dark2'):
  from matplotlib import pyplot as plt
  import seaborn as sns
  df.groupby(colname).size().plot(kind='barh', color=sns.palettes.mpl_palette(mpl_palette_name), figsize=(8*figscale, 4.8*figscale))
  plt.gca().spines[['top', 'right',]].set_visible(False)
  return autoviz.MplChart.from_current_mpl_state()

chart = categorical_histogram(df3, *['assessment_type'], **{})
chart
# Out:
# <img src="...">
#         <script></script>

# %% [markdown]
# # **Courses EDA**

# %%
df4 = pd.read_csv('/content/drive/MyDrive/Data_Sains/BigDataAnalysis/courses.csv')

# %%
df4
# Out:
#    code_module code_presentation  module_presentation_length
# 0          AAA             2013J                         268
# 1          AAA             2014J                         269
# 2          BBB             2013J                         268
# 3          BBB             2014J                         262
# 4          BBB             2013B                         240
# 5          BBB             2014B                         234
# 6          CCC             2014J                         269
# 7          CCC             2014B                         241
# 8          DDD             2013J                         261
# 9          DDD             2014J                         262
# 10         DDD             2013B                         240
# 11         DDD             2014B                         241
# 12         EEE             2013J                         268
# 13         EEE             2014J                         269
# ...

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 3 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   code_module                 22 non-null     object
#  1   code_presentation           22 non-null     object
#  2   module_presentation_length  22 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 656.0+ bytes

# %%
df4.describe()
# Out:
#        module_presentation_length
# count                   22.000000
# mean                   255.545455
# std                     13.654677
# min                    234.000000
# 25%                    241.000000
# 50%                    261.500000
# 75%                    268.000000
# max                    269.000000

# %%
def histogram(df, colname, num_bins=20, figscale=1):
  from matplotlib import pyplot as plt
  df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
  plt.gca().spines[['top', 'right',]].set_visible(False)
  plt.tight_layout()
  return autoviz.MplChart.from_current_mpl_state()

chart = histogram(df4, *['module_presentation_length'], **{})
chart
# Out:
# <img src="...">
#         <script></script>

# %% [markdown]
# # **Student Registration EDA**

# %%
df5 = pd.read_csv('/content/drive/MyDrive/Data_Sains/BigDataAnalysis/studentRegistration.csv')

# %%
df5
# Out:
#       code_module code_presentation  id_student  date_registration  \
# 0             AAA             2013J       11391             -159.0
# 1             AAA             2013J       28400              -53.0
# 2             AAA             2013J       30268              -92.0
# 3             AAA             2013J       31604              -52.0
# 4             AAA             2013J       32885             -176.0
# ...           ...               ...         ...                ...
# 32588         GGG             2014J     2640965               -4.0
# 32589         GGG             2014J     2645731              -23.0
# 32590         GGG             2014J     2648187             -129.0
# 32591         GGG             2014J     2679821              -49.0
# 32592         GGG             2014J     2684003              -28.0
#
#        date_unregistration
# 0                      NaN
# 1                      NaN
# 2                     12.0
# 3                      NaN
# ...

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32593 entries, 0 to 32592
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   code_module          32593 non-null  object
#  1   code_presentation    32593 non-null  object
#  2   id_student           32593 non-null  int64
#  3   date_registration    32548 non-null  float64
#  4   date_unregistration  10072 non-null  float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 1.2+ MB

# %%
df5.describe()
# Out:
#          id_student  date_registration  date_unregistration
# count  3.259300e+04       32548.000000         10072.000000
# mean   7.066877e+05         -69.411300            49.757645
# std    5.491673e+05          49.260522            82.460890
# min    3.733000e+03        -322.000000          -365.000000
# 25%    5.085730e+05        -100.000000            -2.000000
# 50%    5.903100e+05         -57.000000            27.000000
# 75%    6.444530e+05         -29.000000           109.000000
# max    2.716795e+06         167.000000           444.000000

# %%
# Membuat bar chart untuk perbandingan
bar_width = 0.35
index = range(len(df5['code_module']))

plt.figure(figsize=(8, 6))
plt.bar(index, df5['date_registration'], bar_width, label='date_registration', color='skyblue')
plt.bar([p + bar_width for p in index], df5['date_unregistration'], bar_width, label='date_unregistration', color='orange')

plt.xlabel('Kelompok')
plt.ylabel('Nilai')
plt.title('Perbandingan antara Data 1 dan Data 2')
plt.xticks([p + bar_width/2 for p in index], df5['code_module'])
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
def violin_plot(df, value_colname, facet_colname, figscale=1, mpl_palette_name='Dark2', **kwargs):
  from matplotlib import pyplot as plt
  import seaborn as sns
  figsize = (12 * figscale, 1.2 * figscale * len(df[facet_colname].unique()))
  plt.figure(figsize=figsize)
  sns.violinplot(df, x=value_colname, y=facet_colname, palette=mpl_palette_name, **kwargs)
  sns.despine(top=True, right=True, bottom=True, left=True)
  return autoviz.MplChart.from_current_mpl_state()

chart = violin_plot(df5, *['date_registration', 'code_module'], **{'inner': 'box'})
chart
# Out:
# <img src="...

# %%
def violin_plot(df, value_colname, facet_colname, figscale=1, mpl_palette_name='Dark2', **kwargs):
  from matplotlib import pyplot as plt
  import seaborn as sns
  figsize = (12 * figscale, 1.2 * figscale * len(df[facet_colname].unique()))
  plt.figure(figsize=figsize)
  sns.violinplot(df, x=value_colname, y=facet_colname, palette=mpl_palette_name, **kwargs)
  sns.despine(top=True, right=True, bottom=True, left=True)
  return autoviz.MplChart.from_current_mpl_state()

chart = violin_plot(df5, *['date_unregistration', 'code_module'], **{'inner': 'box'})
chart
# Out:
# <img src="...

# %% [markdown]
# # **Vle EDA**

# %%
df6 = pd.read_csv('/content/drive/MyDrive/Data_Sains/BigDataAnalysis/vle.csv')

# %%
df6
# Out:
#       id_site code_module code_presentation activity_type  week_from  week_to
# 0      546943         AAA             2013J      resource        NaN      NaN
# 1      546712         AAA             2013J     oucontent        NaN      NaN
# 2      546998         AAA             2013J      resource        NaN      NaN
# 3      546888         AAA             2013J           url        NaN      NaN
# 4      547035         AAA             2013J      resource        NaN      NaN
# ...       ...         ...               ...           ...        ...      ...
# 6359   897063         GGG             2014J      resource        NaN      NaN
# 6360   897109         GGG             2014J      resource        NaN      NaN
# 6361   896965         GGG             2014J     oucontent        NaN      NaN
# 6362   897060         GGG             2014J      resource        NaN      NaN
# 6363   897100         GGG             2014J      resource        NaN      NaN
#
# [6364 rows x 6 columns]

# %%
df6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6364 entries, 0 to 6363
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id_site            6364 non-null   int64
#  1   code_module        6364 non-null   object
#  2   code_presentation  6364 non-null   object
#  3   activity_type      6364 non-null   object
#  4   week_from          1121 non-null   float64
#  5   week_to            1121 non-null   float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 298.4+ KB

# %%
df6.describe()
# Out:
#             id_site    week_from      week_to
# count  6.364000e+03  1121.000000  1121.000000
# mean   7.260991e+05    15.204282    15.214987
# std    1.283151e+05     8.792865     8.779806
# min    5.267210e+05     0.000000     0.000000
# 25%    6.615928e+05     8.000000     8.000000
# 50%    7.300965e+05    15.000000    15.000000
# 75%    8.140162e+05    22.000000    22.000000
# max    1.077905e+06    29.000000    29.000000

# %%
def categorical_histogram(df, colname, figscale=1, mpl_palette_name='Dark2'):
  from matplotlib import pyplot as plt
  import seaborn as sns
  df.groupby(colname).size().plot(kind='barh', color=sns.palettes.mpl_palette(mpl_palette_name), figsize=(8*figscale, 4.8*figscale))
  plt.gca().spines[['top', 'right',]].set_visible(False)
  return autoviz.MplChart.from_current_mpl_state()

chart = categorical_histogram(df6, *['activity_type'], **{})
chart
# Out:
# <img src="...

# %% [markdown]
# # **Student Vle EDA**

# %%
df7 = pd.read_csv('/content/drive/MyDrive/Data_Sains/BigDataAnalysis/studentVle.csv')

# %%
df7
# Out:
#          code_module code_presentation  id_student  id_site  date  sum_click
# 0                AAA             2013J       28400   546652   -10          4
# 1                AAA             2013J       28400   546652   -10          1
# 2                AAA             2013J       28400   546652   -10          1
# 3                AAA             2013J       28400   546614   -10         11
# 4                AAA             2013J       28400   546714   -10          1
# ...              ...               ...         ...      ...   ...        ...
# 10655275         GGG             2014J      675811   896943   269          3
# 10655276         GGG             2014J      675578   896943   269          1
# 10655277         GGG             2014J      654064   896943   269          3
# 10655278         GGG             2014J      654064   896939   269          1
# 10655279         GGG             2014J      654064   896939   269          1
#
# [10655280 rows x 6 columns]

# %%
df7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10655280 entries, 0 to 10655279
# Data columns (total 6 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   code_module        object
#  1   code_presentation  object
#  2   id_student         int64
#  3   id_site            int64
#  4   date               int64
#  5   sum_click          int64
# dtypes: int64(4), object(2)
# memory usage: 487.8+ MB

# %%
df7.describe()
# Out:
#          id_student       id_site          date     sum_click
# count  1.065528e+07  1.065528e+07  1.065528e+07  1.065528e+07
# mean   7.333336e+05  7.383234e+05  9.517400e+01  3.716946e+00
# std    5.827060e+05  1.312196e+05  7.607130e+01  8.849047e+00
# min    6.516000e+03  5.267210e+05 -2.500000e+01  1.000000e+00
# 25%    5.077430e+05  6.735190e+05  2.500000e+01  1.000000e+00
# 50%    5.882360e+05  7.300690e+05  8.600000e+01  2.000000e+00
# 75%    6.464840e+05  8.770300e+05  1.560000e+02  3.000000e+00
# max    2.698588e+06  1.049562e+06  2.690000e+02  6.977000e+03

# %%
sample_size = 10000  # Ganti dengan ukuran sampel yang diinginkan
sampled_data = df7.sample(n=sample_size, random_state=42)

plt.figure(figsize=(8, 6))
plt.bar(sampled_data['sum_click'], sampled_data['code_module'], color='skyblue')
plt.xlabel('sum_click')
plt.ylabel('Code Module')
plt.show()

# %%
sampled_data
# Out:
#         code_module code_presentation  id_student  id_site  date  sum_click
# 1772935         BBB             2014J      678995   913466   138          1
# 6560373         FFF             2013B      498636   526738    38          2
# 5621534         EEE             2013J      576439   551010   201          2
# 4228488         DDD             2013J      568598   673537   193          1
# 8100617         FFF             2013J      583824   716768   160          1
# ...             ...               ...         ...      ...   ...        ...
# 5373805         EEE             2013J     1902240   551010    26         14
# 7332187         FFF             2013J      570878   716216     5          5
# 2570982         CCC             2014J      621884   909232    20          3
# 3823064         DDD             2013J      582160   673537    22          2
# 167370          AAA             2013J     1889511   546692   227          9
#
# [10000 rows x 6 columns]

# %% [markdown]
# # **FINDING CORRELATION**

# %% [markdown]
# # **STUDENT REGISTRATION & STUDENT INFO**

# %% [markdown]
# Melakukan penggambungan data antara Student registration dan student info, lalu di letakkan kedalam variabel baru.

# %%
merge_data = pd.merge(df5, df1, on='id_student', how='inner')

# %% [markdown]
# Mengecek dan menghapus nilai duplikat pada atribut id_student yang merupakan unique value

# %%
merge_data.duplicated('id_student').sum()
# Out:
# 12016

# %%
merge_data = merge_data.drop_duplicates('id_student')

# %%
merge_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 28785 entries, 0 to 40800
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   code_module_x         28785 non-null  object
#  1   code_presentation_x   28785 non-null  object
#  2   id_student            28785 non-null  int64
#  3   date_registration     28747 non-null  float64
#  4   date_unregistration   8968 non-null   float64
#  5   code_module_y         28785 non-null  object
#  6   code_presentation_y   28785 non-null  object
#  7   gender                28785 non-null  object
#  8   region                28785 non-null  object
#  9   highest_education     28785 non-null  object
#  10  imd_band              27814 non-null  object
#  11  age_band              28785 non-null  object
#  12  num_of_prev_attempts  28785 non-null  int64
#  13  studied_credits       28785 non-null  int64
#  14  disability            28785 non-null  object
# ...

# %%
merge_data
# Out:
#       code_module_x code_presentation_x  id_student  date_registration  \
# 0               AAA               2013J       11391             -159.0
# 1               AAA               2013J       28400              -53.0
# 2               AAA               2013J       30268              -92.0
# 3               AAA               2013J       31604              -52.0
# 4               AAA               2013J       32885             -176.0
# ...             ...                 ...         ...                ...
# 40796           GGG               2014J     2640965               -4.0
# 40797           GGG               2014J     2645731              -23.0
# 40798           GGG               2014J     2648187             -129.0
# 40799           GGG               2014J     2679821              -49.0
# 40800           GGG               2014J     2684003              -28.0
#
#        date_unregistration code_module_y code_presentation_y gender  \
# ...

# %% [markdown]
# Pengecekan dan penghapusan nilai null pada data merge

# %%
merge_data.isnull().sum()
# Out:
# code_module_x               0
# code_presentation_x         0
# id_student                  0
# date_registration          38
# date_unregistration     19817
# code_module_y               0
# code_presentation_y         0
# gender                      0
# region                      0
# highest_education           0
# imd_band                  971
# age_band                    0
# num_of_prev_attempts        0
# studied_credits             0
# disability                  0
# final_result                0
# dtype: int64

# %%
merge_data.duplicated().sum()
# Out:
# 0

# %%
merge_data = merge_data.dropna(how='any')

# %%
merge_data.isnull().sum()
# Out:
# code_module_x           0
# code_presentation_x     0
# id_student              0
# date_registration       0
# date_unregistration     0
# code_module_y           0
# code_presentation_y     0
# gender                  0
# region                  0
# highest_education       0
# imd_band                0
# age_band                0
# num_of_prev_attempts    0
# studied_credits         0
# disability              0
# final_result            0
# dtype: int64

# %%
data = pd.DataFrame(merge_data)

# %%
data
# Out:
#       code_module_x code_presentation_x  id_student  date_registration  \
# 2               AAA               2013J       30268              -92.0
# 15              AAA               2013J       65002             -180.0
# 25              AAA               2013J       94961             -170.0
# 35              AAA               2013J      106247                5.0
# 47              AAA               2013J      129955             -197.0
# ...             ...                 ...         ...                ...
# 40784           GGG               2014J     2338614              -23.0
# 40785           GGG               2014J     2342238              -45.0
# 40786           GGG               2014J     2357806             -128.0
# 40794           GGG               2014J     2608143              -45.0
# 40799           GGG               2014J     2679821              -49.0
#
#        date_unregistration code_module_y code_presentation_y gender  \
# ...

# %% [markdown]
# Pada bar chart dibawah dapat dilihat bahwa dari 8726 instance menyatakan bahwa hanya sebagian kecil siswa yang menyandang disabilitas dengan angka dibawah 1000 instance

# %%
count_disability = data['disability'].value_counts()

plt.figure(figsize=(8, 6))
plt.bar(count_disability.index, count_disability.values, color=['blue', 'orange'])
plt.title('Jumlah Siswa Disabilitas')
plt.show()

# %% [markdown]
# # **ASSESSMENT & STUDENT ASSESSMENT**

# %% [markdown]
# Melakukan merging data antara assessment dengan student assessment berdasarkan atribut id_assesment dengan cara inner join

# %%
merge_data_nd = pd.merge(df2, df3, on='id_assessment', how='inner')

# %% [markdown]
# Melakukan pengecekan dan penghapusan nilai duplikat dan nilai null pada merge data

# %%
merge_data_nd.duplicated('id_assessment').sum()
# Out:
# 173724

# %%
merge_data_nd = merge_data_nd.drop_duplicates('id_assessment')

# %%
merge_data_nd.isnull().sum()
# Out:
# id_assessment        0
# id_student           0
# date_submitted       0
# is_banked            0
# score                0
# code_module          0
# code_presentation    0
# assessment_type      0
# date                 3
# weight               0
# dtype: int64

# %%
merge_data_nd = merge_data_nd.dropna(how='any')

# %%
merge_data_nd.isnull().sum()
# Out:
# id_assessment        0
# id_student           0
# date_submitted       0
# is_banked            0
# score                0
# code_module          0
# code_presentation    0
# assessment_type      0
# date                 0
# weight               0
# dtype: int64

# %% [markdown]
# merge data dimasukkan ke dalam variabel data yang baru

# %%
data2 = pd.DataFrame(merge_data_nd)

# %% [markdown]
# Membuat atribut baru bernama 'status' berdasarkan atribut score. Jika nilai dari atribut 'score' berada di bawah 40 maka siswa tersebut dinyatakan gagal

# %%
data2['status'] = data2.apply(lambda row: 'FAIL' if row['score'] < 40 else 'PASS', axis=1)

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 185 entries, 0 to 173568
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id_assessment      185 non-null    int64
#  1   id_student         185 non-null    int64
#  2   date_submitted     185 non-null    int64
#  3   is_banked          185 non-null    int64
#  4   score              185 non-null    float64
#  5   code_module        185 non-null    object
#  6   code_presentation  185 non-null    object
#  7   assessment_type    185 non-null    object
#  8   date               185 non-null    float64
#  9   weight             185 non-null    float64
#  10  status             185 non-null    object
# dtypes: float64(3), int64(4), object(4)
# memory usage: 17.3+ KB

# %%
data2
# Out:
#         id_assessment  id_student  date_submitted  is_banked  score  \
# 0                1752       11391              18          0   78.0
# 359              1753      704156              56          0   68.0
# 701              1754      564450             114          0   64.0
# 1032             1755       11391             164          0   85.0
# 1335             1756      704156             215          0   70.0
# ...               ...         ...             ...        ...    ...
# 171696          37439       31205             129          0  100.0
# 172200          37440      653435             173          0  100.0
# 172679          37441      561419             228          0   60.0
# 173152          37442       60162             220          0   60.0
# 173568          37443      653435             230          0   80.0
#
#        code_module code_presentation assessment_type   date  weight status
# 0              AAA             2013J             TMA   19.0    10.0   PASS
# ...

# %% [markdown]
# Dapat dilihat dari bar chart bahwa hanya sedikit siswa yang dinyatakan gagal pada assessment dengan nilai dibawah 25 instance

# %%
count_status = data2['status'].value_counts()

plt.figure(figsize=(8, 6))
plt.bar(count_status.index, count_status.values, color=['blue', 'red'])
plt.title('Jumlah Siswa Lulus')
plt.show()

# %% [markdown]
# # **STUDENT VLE & VLE**

# %% [markdown]
# Melakukan merging data antara Student Vle dan Vle berdasarkan atribut 'id_site' menggunakan inner join

# %%
merge_data_rd = pd.merge(df7, df6, on='id_site', how='inner')

# %% [markdown]
# Melakukan pengecekan nilai duplikat dan nilai null pada data merge

# %%
merge_data_rd.duplicated().sum()
# Out:
# 787170

# %%
merge_data_rd.isnull().sum()
# Out:
# code_module_x                0
# code_presentation_x          0
# id_student                   0
# id_site                      0
# date                         0
# sum_click                    0
# code_module_y                0
# code_presentation_y          0
# activity_type                0
# week_from              9269544
# week_to                9269544
# dtype: int64

# %%
merge_data_rd = merge_data_rd.drop_duplicates()

# %%
merge_data_rd = merge_data_rd.dropna(how='any')

# %%
print("duplicate",merge_data_rd.duplicated().sum())
print("null val\n",merge_data_rd.isnull().sum())
# Out:
# duplicate 0
# null val
#  code_module_x          0
# code_presentation_x    0
# id_student             0
# id_site                0
# date                   0
# sum_click              0
# code_module_y          0
# code_presentation_y    0
# activity_type          0
# week_from              0
# week_to                0
# dtype: int64

# %% [markdown]
# Data yang sudah dilakukan proses merge dimasukkan kedalam variabel dataframe baru

# %%
data3 = pd.DataFrame(merge_data_rd)

# %%
data3
# Out:
#          code_module_x code_presentation_x  id_student  id_site  date  \
# 64022              AAA               2013J       32885   546681   -10
# 64023              AAA               2013J       38053   546681   -10
# 64024              AAA               2013J       58873   546681   -10
# 64025              AAA               2013J       59185   546681   -10
# 64026              AAA               2013J       62155   546681   -10
# ...                ...                 ...         ...      ...   ...
# 10560448           GGG               2014J      691229   897052   222
# 10560449           GGG               2014J     1777563   897052   223
# 10560450           GGG               2014J      625530   897052   223
# 10560451           GGG               2014J      682625   897052   226
# 10560452           GGG               2014J      656936   897052   228
#
#           sum_click code_module_y code_presentation_y activity_type  \
# ...

# %%
data3.describe()
# Out:
#          id_student       id_site          date     sum_click     week_from  \
# count  1.338264e+06  1.338264e+06  1.338264e+06  1.338264e+06  1.338264e+06
# mean   7.216670e+05  7.777733e+05  9.412800e+01  4.770270e+00  1.059846e+01
# std    5.379384e+05  1.097500e+05  7.465199e+01  9.210882e+00  8.378734e+00
# min    6.516000e+03  5.267550e+05 -2.500000e+01  1.000000e+00  0.000000e+00
# 25%    5.408000e+05  7.163250e+05  2.700000e+01  1.000000e+00  3.000000e+00
# 50%    6.020660e+05  7.796230e+05  8.500000e+01  2.000000e+00  9.000000e+00
# 75%    6.516550e+05  8.826110e+05  1.520000e+02  4.000000e+00  1.800000e+01
# max    2.698588e+06  9.263330e+05  2.690000e+02  1.517000e+03  2.900000e+01
#
#             week_to
# count  1.338264e+06
# mean   1.063482e+01
# std    8.351318e+00
# min    0.000000e+00
# 25%    3.000000e+00
# 50%    9.000000e+00
# 75%    1.800000e+01
# max    2.900000e+01

# %% [markdown]
# Dapat dilihat pada histogram dibawah bahwa interaksi siswa terhadap materi yang diberikan tertinggi berada pada hari pertama

# %%
plt.figure(figsize=(12, 6))
plt.subplot(2, 2, 1)
sns.histplot(data=data3, x="date", kde=True)
plt.tight_layout()
plt.show()

# %% [markdown]
# # **COURSES & STUDENT REGISTRATION**

# %% [markdown]
# Melakukan merging data antara courses dn student registration berdasarkan 'code_module' menggunakan inner join

# %%
merge_data_fr = pd.merge(df5, df4, on='code_module', how='inner')

# %% [markdown]
# Melakukan pengecekan dan penghapusan nilai duplikat atribut 'id student' dan nilai null pada keseluruhan atribut
# Penghapusan nilai duplikat pada atribut 'id_student' dikarenakan atribut tersebut merupakan unique value

# %%
merge_data_fr.duplicated('id_student').sum()
# Out:
# 85755

# %%
merge_data_fr.isnull().sum()
# Out:
# code_module                       0
# code_presentation_x               0
# id_student                        0
# date_registration               162
# date_unregistration           79405
# code_presentation_y               0
# module_presentation_length        0
# dtype: int64

# %%
merge_data_fr = merge_data_fr.dropna(how='any')

# %%
merge_data_fr = merge_data_fr.drop_duplicates('id_student')

# %% [markdown]
# Memasukkan data hasil merging kedalam atribut dataframe baru

# %%
data4 = pd.DataFrame(merge_data_fr)

# %%
data4
# Out:
#        code_module code_presentation_x  id_student  date_registration  \
# 4              AAA               2013J       30268              -92.0
# 30             AAA               2013J       65002             -180.0
# 44             AAA               2013J       94961             -170.0
# 58             AAA               2013J      106247                5.0
# 82             AAA               2013J      129955             -197.0
# ...            ...                 ...         ...                ...
# 114489         GGG               2014J     2338614              -23.0
# 114492         GGG               2014J     2342238              -45.0
# 114495         GGG               2014J     2357806             -128.0
# 114519         GGG               2014J     2608143              -45.0
# 114534         GGG               2014J     2679821              -49.0
#
#         date_unregistration code_presentation_y  module_presentation_length
# ...

# %%
data4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9052 entries, 4 to 114534
# Data columns (total 7 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   code_module                 9052 non-null   object
#  1   code_presentation_x         9052 non-null   object
#  2   id_student                  9052 non-null   int64
#  3   date_registration           9052 non-null   float64
#  4   date_unregistration         9052 non-null   float64
#  5   code_presentation_y         9052 non-null   object
#  6   module_presentation_length  9052 non-null   int64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 565.8+ KB

# %% [markdown]
# Dapat dilihat pada histogram bahwa lamanya modul presentation dalam hitungan hari berkisar pada 268 hari.

# %%
plt.figure(figsize=(12, 6))
plt.subplot(2, 2, 1)
sns.histplot(data=data4, x="module_presentation_length", kde=True)
plt.tight_layout()
plt.show()
